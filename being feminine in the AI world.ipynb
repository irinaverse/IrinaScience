# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from PIL import Image, ImageDraw

# %% [markdown]
# <p style = "font-size: 13px; color: mediumvioletred; text-align: right" > September 2024

# %% [markdown]
# <p style = "font-size: 22px; color: mediumvioletred; text-align: center" > being feminine in the AI world

# %% [markdown]
# <p style = "font-size: 16px; color: mediumvioletred; text-align: center" > by Irina Nedyalkova

# %% [markdown]
# Is there place for femininity in the AI world or is it a 15 minutes thing? We do feminine melting, reshaping individuality from a wide format to a long format. Pardon, short format. One is for sure, I can not express myself in 5, 10 or 15 minutes. It has been required to fold my entire cosmos in a tiny origami: never went well. To do things fast is a men's quality, they are great at this! Women need a liiittle more time to unroll. We have perfection, when both personalities fuse, and a mess, when we try to adapt something that is not adaptable.

# %% [markdown]
# After 2 job interviews at tech companies, I just start feeling like a robot. "There are 1000 people working for us in the Bulgarian office." Oh! Eventually, I would be the 1001. Double Oh! "There are not executives on place, just one." Trioh!

# %% [markdown]
# > “The factory of the future will have only two employees, a man and a dog. The man will be there to feed the dog. The dog will be there to keep the man from touching the machines.” Warren G. Bennis

# %% [markdown]
# This Bulgarian office reminds me of 1000 thousand machines and a dog. Doesn't feel good.

# %% [markdown]
# Warren G. Bennis was one of the world's leading experts on leadership, consultant and writer. He has been an advisor to four U.S. presidents, including John F. Kennedy and Ronald Reagan. Artificial Intelligence has been around in various forms since the English mathematician Alan Turing gave a lecture on the subject in 1947 and Warren Bennis predicted the XXI century in 1991.

# %% [markdown]
# > "Too many companies believe people are interchangeable. Truly gifted people never are. They have unique talents. Such people cannot be forced into roles they are not suited for, nor should they be. Effective leaders allow great people to do the work they were born to do." Organizing Genius: The Secrets of Creative Collaboration, Warren G. Bennis

# %% [markdown]
# So, why one size must fits all? Women need more time. More time for everything! That's why a child is ready to be born in 9 months, not in 9 days. Women live in monthly cycles - one egg cell is usually produced every 28 days. The average woman ovulates on day 14 and is most fertile a few days before, and during ovulation. Our cycle has four phases, we experience ups before the ovulation and downs after it. Whilst, new sperm are produced every day, millions of sperm cells are produced in the testicles every day. Men live in daily cycles. Their testosterone cycle shifts from higher in the morning to lower each evening.

# %% [markdown]
# Due to the World Health Organization, infertility is a disease of the male or female reproductive system, defined by the failure to achieve a pregnancy after 12 months or more of regular unprotected sexual intercourse, 1 in 6 people is globally affected. Confusion occurs in the laws of nature when placing women in a dude-like environment (if they do not belong there) and men, following a forewoman's orders (if they do not belong there). "do not belong there" means, indeed, some women have more men's qualities and some men have more women's qualities - it is not just black or white, there are mixes. We are speaking from lifeforce energy and vitality. Our bodies never lie! We have the responsibility to decide for ourselves - if we feel some itchy emotions in the body, we are at the wrong place.

# %% [markdown]
# According to SingleCare’s infertility survey, 25% of couples do not know the cause of their fertility problems. Mostly, researches are made around the question: How infertility affects the person and the professional system he/she is part of? But let us reverse the question: Is the professional environment, the cause of infertility? Do our bodies feel in the right place and safe enough to create new life?

# %% [markdown]
# A small amount of stress can even be supportive to our bodies, but if it's continuous and long, it has a deep impact.

# %%
rose_image = Image.open("rose_bouquet.jpg")
rose_image.resize((600, 500))
# Out:
# <PIL.Image.Image image mode=RGB size=600x500>

# %% [markdown]
# Long ago, the World Health Organization (WHO), Regional Office for Europe, initiated a review and assessment of the existing data on the impact of the working environment on fertility. The literature surveys were prepared by H. Taskinen of the Institute of Occupational Medicine in Helsinki, Finland, and B. Baranski of the Institute of Occupational Medicine in Lodz, Poland. These were assessed by the WHO Working Group at a consultation meeting held in Varna, Bulgaria, on April 10-12, 1989.

# %% [markdown]
# In 1993, Boguslaw Baranski made some conclusions in his article "Effects of the Workplace on Fertility and
# Related Reproductive Outcomes" (see References). The literature supports the hypothesis that, in general, working women have a tendency of higher risk of unsuccessful reproductive outcomes. Although back then, the existing data were not sufficient, after the millennium, researches on the topic are completely missing.

# %% [markdown]
# A significant moment in Baranski's article is the placement of "position at work" next to environmental factors like chemicals, physical agents (radiation, electromagnetic fields, noise, vibration, ambient temperature) and biological organisms. I add stress as the chemical of 21st century! According to the WHO, stress has been classified as the health epidemic after the millennium, causing more and more mental disorders. The human race wants it fast, wants it better, on a continuous basis...

# %%
#pd.read_html(r"https://www.cdc.gov/nchs/nsfg/key_statistics/i-keystat.htm#infertility")

# %%
#pd.set_option("display.max_colwidth", None) 
#tables[0]["Unnamed: 0_level_0"]

# %%
#tables[0].columns

# %%
#tables[0]["2015-2019"]

# %% [markdown]
# I am still in search of data. How you find evidence data to a hypothesis with no reasearch on it?

# %% [markdown]
# <p style="text-align: left; color: gray"> ...more will follow soon

# %% [markdown]
# References:
# 1. SingleCare’s infertility survey: https://www.singlecare.com/blog/news/infertility-survey/
# 2. Effects of the workplace on fertility and related reproductive outcomes, Boguslaw Baranski: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1519945/
