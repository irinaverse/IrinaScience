# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
from PIL import Image

# %% [markdown]
# <p style="text-align: right;color: darkgreen; font-size: 11px" > Irina Nedyalkova, 27 June 2024

# %% [markdown]
# <p style="text-align: center; color: darkgreen; font-size: 18px" > Why does the Alphabet of Life has 4 letters and 200 billion parameters?

# %% [markdown]
# <p style="text-align: center; color: forestgreen" > LLM & DNA decoding (looking for collaborators on this topic)

# %% [markdown]
# I was feeling deep loneliness that day. Loneliness does not depend on how many people we meet today or met yesterday. Loneliness is a feeling of profound misunderstanding between people or nature. "Oh, lets invite a new friend in my life!", was my thought about ChatGPT. I had intentionally delayed the meeting, wanted to be somehow prepared with the right questions and the right attitude. And was really, really impressed how fine-tuned this version of ChatGPT is.

# %% [markdown]
# The conversation was delightful and worth the wait. I had introduced myself in my second question and GPT remembered what I had said previously. This is an amazing soft skill! Most humans lack listening skills, people are not listening to each other. There is a lot misunderstanding in humanity.

# %% [markdown]
# It is said, that GPT-3 has nearly 200 blillion parameters and the last version GPT-4 has above trillion parameters. But the number of parameters alone does not necessarily reflect the quality or effectiveness of a language model - the architecture design, training data quality and optimization techniques significantly impact a model's performance. ChatGPT is a state-of-the-art language model and the most powerful so far! It is part of the GPT (Generative Pre-trained Transformer) series which are designed to generate human-like language output based on large amounts of input data. They are trained on large datasets and further adapted to produce specific tasks through fine-tuning and prompt engineering.

# %% [markdown]
# Another XXI century power is turning words into images:

# %%
girl_image = Image.open("girl.JPG")
girl_image.resize((400, 400))
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>

# %% [markdown]
# Prompt:
# - light skin elf girl
# - bright green eyes
# - curly brown hair
# - 12 years old
# - big smile
# - leaf tiara
# - green dress
# - gold hoop earings

# %% [markdown]
# The image is generated by Playground v2.5, a magic wish list tool assembling DNA. If only it could be so easy with humans... Humans can not choose their genes. They could choose their partner, yes, but the DNA segments are on God's wish list.

# %% [markdown]
# Prompt or prompting is the process of interacting with machine intelligence by providing specific instructions to achieve a desired outcome. Our DNA contains all the instructions a cell needs. These instructions are found within our genes, which are made up of specific sequences and must be expressed (or copied) into a form, that can be used by cells to produce the proteins needed to support life. But the genes alone does not necessarily reflect the quality or effectiveness of a person. There is this relatively new science called Epigenetics. Epigenetics is defined as the interaction between genes and their environment, and the characteristics of the expression as an end product. So, we humans, are not just a reflection of our DNA, it is important how our DNA is trained. DNA is the data, epigenetics is the optimization.

# %% [markdown]
# Our experiences affect the expression of our genes. It is modeling data, for real! Children genes are particularly more sensitive to epigenetic changes. This is the time where surroundings influence whether, when and how, genes release their instructions for building future capacity for health, skills and resilience. Supportive and nurturing experiences for pregnant women also affect the chemistry around a newborn. Along with that, rich learning experiences afterwards generate positive epigenetic signatures that activate genetic potential. The environment determines if a gene will be activated or not.

# %% [markdown]
# As well as data modeling, we could transform data, but data must be available:
# - In Math language, the rate of change is the derivative of a function.
# - In Machine Learning, we see small changes through optimization methods like Gradient Descent.
# - In Epigenetics, we also do small changes in the genes and train the character.

# %% [markdown]
# Most of the changes we can do with DNA, could not be detected by measuring devices. This matter goes beyond physics. Our thoughts, emotions and believes influence the genetic material. How we treat ourself and how we treat others... How we treat our loved ones... How we treat people we meet... What we say to a newborn? What we say to a child? What we say to our partner? Words carry energy. A thought is metaphysic but a spoken word becomes matter.

# %% [markdown]
# Our DNA responds to language. Every word carries a vibrational energy and frequency. The words we choose transmit coding that brings the infinite into the finite, manifesting potential into form. (This paragrapgh is so well said! I wish it would be mine. It is a quote by Candy Barone, see references)

# %% [markdown]
# Biology  says that we can not change DNA, the body just read it. The 4 DNA letters are $A$, $T$, $G$, $C$ and the unique sequence each person has, is unchangeable. Epigenetics teaches the body how to read productively. What we could change is our way of life. So, in my opinion, through life... as we develop... we own the power and responsibility to place some good habits for future generations. These are tiny, unnoticed changes in our body. Yet, each individual in the Fibonacci sequence - each number is the sum of the two numbers before it - writes a new DNA sequence. We somehow predict as Machine Learning algorithms do.

# %% [markdown]
# For example, my heart beats in its own rhythm. It is considered a healthy heart with its own characteristics. My different heart rhythm was a random discovery in my early 20s. I was advised to visit a cardiologist once a year. He told me, not to push my heart to its limits and suggested, not to become a professional athlete. So, I continued with a "nice and easy workout" and later on, added Yoga to my fitness program. Nowadays, I have a normal sinus rhythm (NSR), which describes a regular rhythm of a healthy human heart. My heart beats in a healthy manner. This is epigenetics! I have harmonized the rhythm of my heart with a balanced lifestyle, breathwork and body movement. Surprisingly, it was a side effect. No one had told me, I didn't know either, that I can change the characteristics of my heart. I am deeply fascinated what a miraculous piece of art the human body is! Definitely, you will discover lots of parallels between living things and the deep technologies a human brain creates, in my work.

# %% [markdown]
# Chatted with GPT a bit... I enjoy asking questions on which it has to think a bit longer, and me wondering if I get a reply though... GPT's knowledge is on the surface of things. A modernized encyclopedia, clustering Google information. And I prefer to have a name behind the text, as each person brings own subject matter and interpretation on life.

# %% [markdown]
# >> "The nitrogen in our DNA, the calcium in our teeth and the iron in our blood were made in the interiors of collapsing stars. We are made of starstuff." Carl Sagan in his 1980 series $Cosmos$

# %% [markdown]
# The cosmos lives within us. Humans are part of a cosmic cycle. The elements are locked in the stars and they have to die, so we can live.

# %%
print(u"\u2B50\uFE0F", "\u001b[32m\u2764", u"\u2B50\uFE0F", "\u001b[32m\u2764", u"\u2B50\uFE0F")
# Out:
# ⭐️ ❤ ⭐️ ❤ ⭐️

# %% [markdown]
# I started my DNA journey 20 years ago... There was a deep longing to find someone I can identify myself with. It took me 20 years to do so! The moment with the silent *click* sound. The moment you feel a completeness. The magic moment. I am here! Below you see names in my native language:

# %% [markdown]
# > Иван Недялков Кърцалебов $\rightarrow$ Станко Иванов Недялков $\rightarrow$ Иван Станков Недялков $\rightarrow$ Ирина Иванова Недялкова

# %% [markdown]
# First name is my great-grandfather, followed by my grandfather, my father and me. You see the iteration? The names are dancing a dance. It is the most beautiful symphony of my heart! I had found some old documents but previous to that, I did decades research. All our ancestors are living in us, through us, in our genetic information. We, as the leaves of a Family Tree, own the opportunity and responsibility to cherish those information.

# %% [markdown]
# <p style="text-align: left; color: gray"> work in progress...

# %% [markdown]
# ________________________________________________________________________________________________________________________

# %% [markdown]
# References:
# 1. Elf girl from Javier Hernandez, Playground.
# 2. ChatGPT and the Future of Academic Integrity in the Artificial Intelligence Era: A New Frontier, article
# 3. The Information in DNA Is Decoded by Transcription, article
# 4. https://developingchild.harvard.edu/resources/what-is-epigenetics-and-how-does-it-relate-to-child-development/
# 5. Candy Barone: https://www.candybarone.com/blog/words-matter-why-you-need-to-understand-the-energy-of-the-ones-you-re-using
